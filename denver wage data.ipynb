# %%
import pandas
f = r'C:\Users\jflan\Downloads\Employment_Wages_in_Colorado.csv'

# %%
import matplotlib.pyplot as plt

# %%
df= pandas.read_csv(f)

# %%
print(df.keys())
# Out:
# Index(['stateabbrv', 'statename', 'stfips', 'areaname', 'areatype',
#        'areatyname', 'area', 'periodyear', 'periodtype', 'pertypdesc',
#        'period', 'indcodty', 'indcode', 'indcodetitle', 'occodetype',
#        'occodetydesc', 'occcode', 'codetitle', 'wagesource', 'wagesrdesc',
#        'ratetype', 'ratetydesc', 'empcount', 'response', 'mean', 'entrywg',
#        'experience', 'pct10', 'pct25', 'median', 'pct75', 'pct90', 'udpct',
#        'udpctwage', 'udrnglopct', 'udrnghipct', 'udrngmean', 'wpctrelerr',
#        'epctrelerr', 'panelcode'],
#       dtype='object')

# %%
df.hist(column= 'mean',by='areaname',bins=10,grid=False, figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002326D796630>,
# ...
#       dtype=object)

# %%
df.plot.scatter(x='periodyear',y='median')

# %%
df.pivot_table(values='mean',index='areaname',columns='periodyear')
# Out:
# periodyear                             2009          2010          2011  \
# areaname
# Boulder-Longmont MSA           27538.543265  27537.291209  27918.817356
# Central  Colorado              21768.529629  21151.485418  21567.699645
# Colorado                       26310.353462  26884.347759  27571.637865
# Colorado Springs MSA           24643.018379  26187.290303  26465.877032
# Denver - Aurora MSA            27227.229804  28348.610417  28629.217578
# Eastern and Southern Colorado  20737.691603  21706.544573  21991.653578
# Fort Collins-Loveland MSA      24768.916189  25009.266717  26403.149974
# Grand Junction MSA             22536.064705  23305.217593  23740.282021
# Greeley MSA                    23751.305201  23682.816753  24524.468415
# North Central  Colorado                 NaN  25669.118432  25603.545970
# Northwest Colorado                      NaN           NaN           NaN
# Pueblo MSA                     23508.699819  23524.470978  23138.879314
# ...

# %%
df.pivot_table(values='empcount',index='areaname',columns='periodyear')
# Out:
# periodyear                            2009         2010         2011  \
# areaname
# Boulder-Longmont MSA            754.125964  1142.686763  1144.711168
# Central  Colorado               192.068966   290.754717   293.639053
# Colorado                       6371.461818  9435.934230  9459.316679
# Colorado Springs MSA           1039.956188  1629.078180  1587.460497
# Denver - Aurora MSA            3886.001635  6045.467938  6099.870578
# Eastern and Southern Colorado   413.289256   626.314908   638.296422
# Fort Collins-Loveland MSA       641.571038   976.267218   933.171691
# Grand Junction MSA              393.802083   594.552239   549.198606
# Greeley MSA                     437.608025   719.792746   726.526138
# North Central  Colorado                NaN   682.932455   683.432836
# Northwest Colorado                     NaN          NaN          NaN
# Pueblo MSA                      368.929220   561.340580   557.635379
# ...

# %%
df.pivot_table(values='experience',index='areaname',columns='periodyear')
# Out:
# periodyear                             2009          2010          2011  \
# areaname
# Boulder-Longmont MSA           31445.883663  31587.693633  32255.701133
# Central  Colorado              24917.443820  24155.366792  24616.998254
# Colorado                       30460.631978  31065.722877  32094.943338
# Colorado Springs MSA           28259.173352  30087.645906  30380.563903
# Denver - Aurora MSA            31291.336615  32602.909546  33341.573778
# Eastern and Southern Colorado  23889.545240  24319.440573  25333.523083
# Fort Collins-Loveland MSA      27977.598784  28654.939225  29909.763606
# Grand Junction MSA             25561.136354  26519.356835  27488.422108
# Greeley MSA                    27465.878889  27325.110846  28322.734452
# North Central  Colorado                 NaN  29636.980380  29544.028159
# Northwest Colorado                      NaN           NaN           NaN
# Pueblo MSA                     27104.566534  27103.601178  26779.284116
# ...
